# %% [markdown]
# In this notebook, I'll be attempting my first Kaggle challenge using the Titanic data set.
#
# I will be utilizing multiple machine learning approaches and a neural network approach and see which is the the most optimal for this data set. This will be assessed by test accuracy.

# %%
#utility libraries
import numpy as np
import random as rndm
import time

#visualization
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#machine learning libraries
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

#deep learning libraries
import tensorflow
import keras

# %% [markdown]
# Loading the data set.

# %%
train_data = pd.read_csv('../input/titanic/train.csv')
test_data = pd.read_csv('../input/titanic/test.csv')
gender_data = ('../input/titanic/gender_submission.csv')
#combine = [train_data, test_data]

# %% [markdown]
# Analyze the data. We can take a quick peek at the head and tail of the data.

# %%
train_data.head()
#train_data.tail()

# %% [markdown]
# Printing the data to see what features we're working with.

# %%
print(train_data.columns.values)
